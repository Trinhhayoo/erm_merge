# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/emr-merge/EMR_Merging/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/merge_gpt_glue.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/inference_plms_glue.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/merge_roberta_glue.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/utils/glue_data_loader.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/utils/metrics.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/utils/load_config.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/utils/evaluate_llms_utils.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/utils/customized_trainers.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/utils/utils.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/gitattributes
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/model.safetensors
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_rte/results.csv
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/gitattributes
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/model.safetensors
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mnli/results.csv
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/gitattributes
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/model.safetensors
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qnli/results.csv
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/gitattributes
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/model.safetensors
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_mrpc/results.csv
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/gitattributes
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/model.safetensors
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_qqp/results.csv
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/gitattributes
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/model.safetensors
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_sst2/results.csv
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/gitattributes
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/model.safetensors
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/gpt2/gpt2_cola/results.csv
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/trainer_state.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/training_args.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/tokenizer.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/pytorch_model.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qnli/roberta-base_lr1e-05/qnli_roberta-base_lr1e-05_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/trainer_state.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/training_args.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/tokenizer.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/pytorch_model.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/sst2/roberta-base_lr1e-05/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/trainer_state.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/training_args.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/tokenizer.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/pytorch_model.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/rte/roberta-base_lr1e-05/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/trainer_state.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/training_args.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/tokenizer.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/pytorch_model.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/qqp/roberta-base_lr1e-05/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/trainer_state.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/training_args.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/tokenizer.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/pytorch_model.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/stsb/roberta-base_lr1e-05/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/trainer_state.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/training_args.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/tokenizer.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/pytorch_model.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mnli/roberta-base_lr1e-05/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/trainer_state.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/training_args.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/tokenizer.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/pytorch_model.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/cola/roberta-base_lr1e-05/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/merges.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/trainer_state.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/training_args.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/tokenizer.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/vocab.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/tokenizer_config.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/pytorch_model.bin
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/ckpts/roberta/mrpc/roberta-base_lr5e-05/special_tokens_map.json
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/models/models.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/save_merge_logs/roberta-base/1728454865.5160053.log
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/save_merge_logs/gpt2/1728455822.8117764.log
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/model_merging_methods/merging_methods.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/model_merging_methods/mask_weights_utils.py
# /kaggle/input/emr-merge/EMR_Merging/merge_lm/model_merging_methods/task_vector.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/checkpoints/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/logs/ViT-B-16/log_20240726_043847_emr_merging.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/logs/ViT-L-14/log_20240726_033709_emr_merging.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/logs/ViT-B-32/log_20240726_031216_emr_merging.txt
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/task_vectors.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/main_emr_merging.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/modeling.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/main_emr_30_vits.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/heads.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/eval.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/main_layer_wise_adamergingpp.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/main_layer_wise_adamerging.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/ties_merging_utils.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/utils.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/args.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/main_task_arithmetic.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/main_ties_merging.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/templates.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/svhn.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/dtd.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/gtsrb.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/sun397.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/registry.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/mnist.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/common.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/resisc45.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/eurosat.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/src/datasets/cars.py
# /kaggle/input/emr-merge/EMR_Merging/merge_vit/data/README.md
# /kaggle/input/emr-merge/EMR_Merging/.git/config
# /kaggle/input/emr-merge/EMR_Merging/.git/packed-refs
# /kaggle/input/emr-merge/EMR_Merging/.git/HEAD
# /kaggle/input/emr-merge/EMR_Merging/.git/index
# /kaggle/input/emr-merge/EMR_Merging/.git/description
# /kaggle/input/emr-merge/EMR_Merging/.git/info/exclude
# /kaggle/input/emr-merge/EMR_Merging/.git/refs/heads/main
# /kaggle/input/emr-merge/EMR_Merging/.git/refs/remotes/origin/HEAD
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/pre-merge-commit.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/update.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/pre-push.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/pre-rebase.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/pre-applypatch.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/push-to-checkout.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/pre-commit.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/commit-msg.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/post-update.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/pre-receive.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/fsmonitor-watchman.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/hooks/applypatch-msg.sample
# /kaggle/input/emr-merge/EMR_Merging/.git/logs/HEAD
# /kaggle/input/emr-merge/EMR_Merging/.git/logs/refs/heads/main
# /kaggle/input/emr-merge/EMR_Merging/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/emr-merge/EMR_Merging/.git/objects/pack/pack-7d1d2fbff5ed2cf4f05216127fee648ee009d15e.pack
# /kaggle/input/emr-merge/EMR_Merging/.git/objects/pack/pack-7d1d2fbff5ed2cf4f05216127fee648ee009d15e.idx
# /kaggle/input/emr-merge/EMR_Merging/png/method-main.jpg
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/modeling_utils.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/run_beit3_finetuning.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/make_json.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/script_vqav2.sh
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/randaug.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/script_nlvr2.sh
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/README.md
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/merge_beit.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/modeling_finetune.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/script_in1k.sh
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/hendlers.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/engine_for_finetuning.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/utils.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/datasets.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/script_captioning.sh
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/handlers.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/glossary.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/optim_factory.py
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/script_retrieval.sh
# /kaggle/input/emr-merge/EMR_Merging/merge_beit3/model_weights/README.md
